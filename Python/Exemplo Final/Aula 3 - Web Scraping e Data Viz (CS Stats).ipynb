# %%
# !python --version
# Out:
# Python 3.11.7

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (4.19.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.18)
# Requirement already satisfied: trio~=0.17 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from beautifulsoup4) (2.5)

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from requests->webdriver-manager) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (from requests->webdriver-manager) (2024.2.2)

# %%
# !pip install fake_useragent
# Out:
# Requirement already satisfied: fake_useragent in c:\programdata\anaconda3\envs\fema-si\lib\site-packages (1.5.1)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service as ChromeService

from webdriver_manager.chrome import ChromeDriverManager

from bs4 import BeautifulSoup

# %%
from datetime import datetime

# %%
import re

# %%
from fake_useragent import UserAgent

# %%
import pandas as pd

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
def web_driver(headless=True):
    options = webdriver.ChromeOptions()
    options.add_argument('--verbose')
    options.add_argument('--no-sandbox')
    if headless:
        options.add_argument('--headless')
    options.add_argument("--disable-extensions")
    options.add_argument("--disable-gpu")
    options.add_argument("--disable-software-rasterizer")
    # options.add_argument('--window-size=1920, 1200')
    options.add_argument("--start-maximized");
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--lang=pt-BR')
    # options.add_argument('--lang=en-US')

    random_user_agent = UserAgent().random
    options.add_argument(f'user-agent={random_user_agent}')
    
    # driver = webdriver.Chrome(options=options)
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    
    return driver

def open_page(url, headless=True):
  driver = web_driver(headless)
  driver.get(url)
  res = driver.page_source.encode('utf-8')
  soup = BeautifulSoup(res, 'html.parser')
  return driver, soup

def open_browser(url):
  driver = web_driver()
  if url:
      driver.get(url)

def get_page_source(driver):
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, 'html.parser')
    return soup

# %% [markdown]
# ## Players

# %%
driver, soup = open_page('https://www.hltv.org/stats/players?matchType=Majors')
driver.quit()

# %%
player_stats = []

tbl_player_stats = soup.find('table', attrs={'class': 'stats-table player-ratings-table'})
rows_player_stats = tbl_player_stats.find('tbody').find_all('tr')

for row in rows_player_stats:
    cols = row.find_all('td')
    player_id = int(re.search(r'/stats/players/(\d+)/', cols[0].find('a')['href'].strip()).group(1))
    player_name = cols[0].text.strip()
    player_link = 'https://www.hltv.org' + cols[0].find('a')['href'].strip()
    players_teams = list(dict.fromkeys(map(lambda img: img['alt'], cols[1].find_all('img'))))
    player_maps = int(cols[2].text.strip())
    player_rounds = int(cols[3].text.strip())
    player_kd_diff = int(cols[4].text.strip())
    player_kd = float(cols[5].text.strip())
    player_rating = float(cols[6].text.strip())

    player_stat = {
        'player_id': player_id,
        'player_name': player_name,
        'player_link': player_link,
        'player_teams': players_teams,
        'player_maps': player_maps,
        'player_rounds': player_rounds,
        'player_kd_diff': player_kd_diff,
        'player_kd': player_kd,
        'player_kd': player_kd,
        'player_rating': player_rating,
    }
    
    player_stats.append(player_stat)

# %%
# player_stats = player_stats[:5]

# %%
def get_stat(stats, stat_filter):
    return list(filter(lambda s: stat_filter == s.find('span').text.strip(), stats))[0].find_all('span')[1].text.strip()

# %%
from concurrent.futures import ThreadPoolExecutor

def process_player(player):
    print(player['player_link'])
    
    driver, soup = open_page(player['player_link'])
    driver.quit()

    summary_info = soup.find('div', attrs={'class': 'summaryInfoContainer'})

    player_realname = summary_info.find('div', attrs={'class': 'summaryRealname'}).find('div').text.strip()
    player_flag = summary_info.find('img', attrs={'class': 'flag'})['title']
    player_age = summary_info.find('div', attrs={'class': 'summaryPlayerAge'}).text.strip()
    player_age = int(player_age.replace(' years', ''))
    player_yob = int(datetime.now().year - player_age) # yob = year of birth

    player['player_realname'] = player_realname
    player['player_flag'] = player_flag
    player['player_age'] = player_age
    player['player_yob'] = player_yob

    stats = soup.find('div', attrs={'class': 'statistics'}).find_all('div', attrs={'class': 'stats-row'})

    headshot_pct = get_stat(stats, 'Headshot %').replace('%', '')
    stat_adr = get_stat(stats, 'Damage / Round')
    stat_kills = get_stat(stats, 'Total kills')
    stat_deaths = get_stat(stats, 'Total deaths')
    stat_kills_round = get_stat(stats, 'Kills / round')
    stat_assists_round = get_stat(stats, 'Assists / round')
    stat_deaths_round = get_stat(stats, 'Deaths / round')
    
    player['stat_hs_pct'] = headshot_pct
    player['stat_adr'] = stat_adr
    player['stat_kills'] = stat_kills
    player['stat_deaths'] = stat_deaths
    player['stat_kills_round'] = stat_kills_round
    player['stat_assists_round'] = stat_assists_round
    player['stat_deaths_round'] = stat_deaths_round

# %%
import os
os.cpu_count()
# Out:
# 20

# %%
num_threads = 10

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    executor.map(process_player, player_stats)
# Out:
# https://www.hltv.org/stats/players/11893/zywoo?matchType=Majors
# https://www.hltv.org/stats/players/9216/coldzera?matchType=Majors
# https://www.hltv.org/stats/players/7998/s1mple?matchType=Majors
# https://www.hltv.org/stats/players/7592/device?matchType=Majors
# https://www.hltv.org/stats/players/15631/kscerato?matchType=Majors
# https://www.hltv.org/stats/players/3741/niko?matchType=Majors
# https://www.hltv.org/stats/players/2553/snax?matchType=Majors
# https://www.hltv.org/stats/players/3055/flusha?matchType=Majors
# https://www.hltv.org/stats/players/18053/broky?matchType=Majors
# https://www.hltv.org/stats/players/10994/stavn?matchType=Majors
# https://www.hltv.org/stats/players/7594/flamie?matchType=Majors
# https://www.hltv.org/stats/players/18221/spinx?matchType=Majors
# https://www.hltv.org/stats/players/9960/frozen?matchType=Majors
# https://www.hltv.org/stats/players/8918/electronic?matchType=Majors
# https://www.hltv.org/stats/players/11816/ropz?matchType=Majors
# https://www.hltv.org/stats/players/885/olofmeister?matchType=Majors
# https://www.hltv.org/stats/players/13776/jame?matchType=Majors
# https://www.hltv.org/stats/players/29/f0rest?matchType=Majors
# https://www.hltv.org/stats/players/10394/twistzz?matchType=Majors
# https://www.hltv.org/stats/players/9032/magisk?matchType=Majors
# https://www.hltv.org/stats/players/3972/hunter?matchType=Majors
# https://www.hltv.org/stats/players/8520/naf?matchType=Majors
# https://www.hltv.org/stats/players/18987/b1t?matchType=Majors
# https://www.hltv.org/stats/players/7429/happy?matchType=Majors
# https://www.hltv.org/stats/players/2757/guardian?matchType=Majors
# https://www.hltv.org/stats/players/7528/krimz?matchType=Majors
# https://www.hltv.org/stats/players/2469/cajunb?matchType=Majorshttps://www.hltv.org/stats/players/39/get-right?matchType=Majors
#
# https://www.hltv.org/stats/players/7167/kennys?matchType=Majors
# https://www.hltv.org/stats/players/13602/nicoodoz?matchType=Majors
# https://www.hltv.org/stats/players/16947/perfecto?matchType=Majors
# https://www.hltv.org/stats/players/317/pashabiceps?matchType=Majors
# https://www.hltv.org/stats/players/7398/dupreeh?matchType=Majors
# https://www.hltv.org/stats/players/8523/tarik?matchType=Majors
# https://www.hltv.org/stats/players/13915/yekindar?matchType=Majors
# https://www.hltv.org/stats/players/695/allu?matchType=Majors
# https://www.hltv.org/stats/players/1225/shox?matchType=Majors
# https://www.hltv.org/stats/players/12553/yuurih?matchType=Majors
# https://www.hltv.org/stats/players/5386/byali?matchType=Majors
# https://www.hltv.org/stats/players/483/edward?matchType=Majors
# https://www.hltv.org/stats/players/8738/elige?matchType=Majors
# https://www.hltv.org/stats/players/7964/cadian?matchType=Majors
# https://www.hltv.org/stats/players/4954/xyp9x?matchType=Majors
# https://www.hltv.org/stats/players/8528/hobbit?matchType=Majors
# https://www.hltv.org/stats/players/8564/fer?matchType=Majorshttps://www.hltv.org/stats/players/3849/jw?matchType=Majors
#
# https://www.hltv.org/stats/players/7148/friberg?matchType=Majors
# https://www.hltv.org/stats/players/8248/jkaem?matchType=Majors
# https://www.hltv.org/stats/players/2023/fallen?matchType=Majors
# https://www.hltv.org/stats/players/11942/buster?matchType=Majors
# https://www.hltv.org/stats/players/3347/seized?matchType=Majors
# https://www.hltv.org/stats/players/9278/rez?matchType=Majors
# https://www.hltv.org/stats/players/161/taz?matchType=Majors
# https://www.hltv.org/stats/players/7168/nbk?matchType=Majors
# https://www.hltv.org/stats/players/7322/apex?matchType=Majors
# https://www.hltv.org/stats/players/4959/kioshima?matchType=Majors
# https://www.hltv.org/stats/players/334/adren?matchType=Majors
# https://www.hltv.org/stats/players/8183/rain?matchType=Majors
# https://www.hltv.org/stats/players/11840/boombl4?matchType=Majors
# https://www.hltv.org/stats/players/884/xizt?matchType=Majors
# https://www.hltv.org/stats/players/12732/fl1t?matchType=Majors
# https://www.hltv.org/stats/players/1146/dennis?matchType=Majors
# https://www.hltv.org/stats/players/165/neo?matchType=Majors
# https://www.hltv.org/stats/players/14148/sjuush?matchType=Majors
# https://www.hltv.org/stats/players/7412/gla1ve?matchType=Majors
# https://www.hltv.org/stats/players/13239/qikert?matchType=Majors
# https://www.hltv.org/stats/players/7716/chopper?matchType=Majors
# https://www.hltv.org/stats/players/12018/teses?matchType=Majors
# https://www.hltv.org/stats/players/484/zeus?matchType=Majors
# https://www.hltv.org/stats/players/7687/nitr0?matchType=Majors
# https://www.hltv.org/stats/players/9816/aleksib?matchType=Majors
# https://www.hltv.org/stats/players/9217/taco?matchType=Majors
# https://www.hltv.org/stats/players/429/karrigan?matchType=Majors
# https://www.hltv.org/stats/players/12521/art?matchType=Majors
# https://www.hltv.org/stats/players/41/pronax?matchType=Majors

# %%
df_player_stats = pd.DataFrame.from_dict(player_stats)
df_player_stats.sort_values(by=['player_rating', 'player_name'],
                            ascending=[False, True],
                            ignore_index=True, inplace=True)

df_player_stats.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_player_stats = pd.DataFrame.from_dict(player_stats)
#       2 df_player_stats.sort_values(by=['player_rating', 'player_name'],
#       3                             ascending=[False, True],
#       4                             ignore_index=True, inplace=True)
#       6 df_player_stats.head()
#
# NameError: name 'pd' is not defined

# %%
import pickle

with open('df_player_stats.pkl', 'wb') as pkl_file:
    pickle.dump(df_player_stats, pkl_file)

# %% [markdown]
# ## Majors

# %%
driver, soup = open_page('https://www.hltv.org/stats/events?matchType=Majors')
driver.quit()

# %%
events_stats = []

tbl_events_stats = soup.find('table', attrs={'class': 'stats-table events-table'})
rows_events_stats = tbl_events_stats.find('tbody').find_all('tr')

for row in rows_events_stats:
    if not row.find('td', attrs={'class': 'winner-col'}).find('img'):
        continue
    
    event_winner = row.find('td', attrs={'class': 'winner-col'}).find('img')['title'].strip()
    event_name = row.find('td', attrs={'class': 'name-col'}).find('a').text.strip()
    event_link = row.find('td', attrs={'class': 'name-col'}).find('a')['href'].strip()
    event_id = int(re.search(r'&event=(\d+)', event_link).group(1))

    event_stats = {
        'event_id': event_id,
        'event_name': event_name,
        'event_link': 'https://www.hltv.org' + event_link,
        'event_winner': event_winner,
    }

    events_stats.append(event_stats)

# %%
def get_event_metadata(metadata, metadata_filter):
    metadata_info = metadata.find('th', string=metadata_filter)
    return metadata_info.find_next().text.strip() if metadata_info else ''

def process_event(event):
    print(event['event_link'])
    
    driver, soup = open_page(event['event_link'], headless=False)
    driver.quit()

    event_link_details = 'https://www.hltv.org' + soup.find('div', attrs={'class': 'event-hub-bottom'}).find('a')['href']

    driver, soup = open_page(event_link_details, headless=False)
    driver.quit()

    tbl_event_metadata = soup.find('table', attrs={'class': 'table eventMeta'})
    
    event['start_date'] = get_event_metadata(tbl_event_metadata, 'Start date')
    event['end_date'] = get_event_metadata(tbl_event_metadata, 'End date')
    event['teams'] = get_event_metadata(tbl_event_metadata, 'Teams')
    event['prize_pool'] = get_event_metadata(tbl_event_metadata, 'Prize pool')
    event['location'] = get_event_metadata(tbl_event_metadata, 'Location')

# %%
num_threads = 5

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    executor.map(process_event, events_stats)
# Out:
# https://www.hltv.org/stats?matchType=Majors&event=7148
# https://www.hltv.org/stats?matchType=Majors&event=6793
# https://www.hltv.org/stats?matchType=Majors&event=6586
# https://www.hltv.org/stats?matchType=Majors&event=6372
# https://www.hltv.org/stats?matchType=Majors&event=4866
# https://www.hltv.org/stats?matchType=Majors&event=4443
# https://www.hltv.org/stats?matchType=Majors&event=3883
# https://www.hltv.org/stats?matchType=Majors&event=3564
# https://www.hltv.org/stats?matchType=Majors&event=3247
# https://www.hltv.org/stats?matchType=Majors&event=2720
# https://www.hltv.org/stats?matchType=Majors&event=2471
# https://www.hltv.org/stats?matchType=Majors&event=2062
# https://www.hltv.org/stats?matchType=Majors&event=2027
# https://www.hltv.org/stats?matchType=Majors&event=1617
# https://www.hltv.org/stats?matchType=Majors&event=1666
# https://www.hltv.org/stats?matchType=Majors&event=1611
# https://www.hltv.org/stats?matchType=Majors&event=1553
# https://www.hltv.org/stats?matchType=Majors&event=1444
# https://www.hltv.org/stats?matchType=Majors&event=1333
# https://www.hltv.org/stats?matchType=Majors&event=1270

# %%
df_events_stats = pd.DataFrame.from_dict(events_stats)
df_events_stats
# Out:
#     event_id                       event_name  \
# 0       7148    PGL CS2 Major Copenhagen 2024
# 1       6793        BLAST.tv Paris Major 2023
# 2       6586               IEM Rio Major 2022
# 3       6372           PGL Major Antwerp 2022
# 4       4866         PGL Major Stockholm 2021
# 5       4443     StarLadder Major Berlin 2019
# 6       3883                IEM Katowice 2019
# 7       3564                FACEIT Major 2018
# 8       3247               ELEAGUE Major 2018
# 9       2720            PGL Major Krakow 2017
# 10      2471               ELEAGUE Major 2017
# 11      2062             ESL One Cologne 2016
# 12      2027                MLG Columbus 2016
# 13      1617  DreamHack Open Cluj-Napoca 2015
# 14      1666             ESL One Cologne 2015
# 15      1611            ESL One Katowice 2015
# 16      1553            DreamHack Winter 2014
# 17      1444             ESL One Cologne 2014
# 18      1333            EMS One Katowice 2014
# 19      1270            DreamHack Winter 2013
#
#                                                 event_link       event_winner  \
# 0   https://www.hltv.org/stats?matchType=Majors&event=7148      Natus Vincere
# 1   https://www.hltv.org/stats?matchType=Majors&event=6793           Vitality
# 2   https://www.hltv.org/stats?matchType=Majors&event=6586          Outsiders
# 3   https://www.hltv.org/stats?matchType=Majors&event=6372               FaZe
# 4   https://www.hltv.org/stats?matchType=Majors&event=4866      Natus Vincere
# 5   https://www.hltv.org/stats?matchType=Majors&event=4443           Astralis
# 6   https://www.hltv.org/stats?matchType=Majors&event=3883           Astralis
# 7   https://www.hltv.org/stats?matchType=Majors&event=3564           Astralis
# 8   https://www.hltv.org/stats?matchType=Majors&event=3247             Cloud9
# 9   https://www.hltv.org/stats?matchType=Majors&event=2720             Gambit
# 10  https://www.hltv.org/stats?matchType=Majors&event=2471           Astralis
# 11  https://www.hltv.org/stats?matchType=Majors&event=2062                 SK
# 12  https://www.hltv.org/stats?matchType=Majors&event=2027         Luminosity
# 13  https://www.hltv.org/stats?matchType=Majors&event=1617               Envy
# 14  https://www.hltv.org/stats?matchType=Majors&event=1666             fnatic
# 15  https://www.hltv.org/stats?matchType=Majors&event=1611             fnatic
# 16  https://www.hltv.org/stats?matchType=Majors&event=1553               LDLC
# 17  https://www.hltv.org/stats?matchType=Majors&event=1444  Ninjas in Pyjamas
# 18  https://www.hltv.org/stats?matchType=Majors&event=1333         Virtus.pro
# 19  https://www.hltv.org/stats?matchType=Majors&event=1270             fnatic
#
#        start_date       end_date teams  prize_pool  \
# 0   Mar 21st 2024  Mar 31st 2024    16  $1,250,000
# 1   May 13th 2023  May 21st 2023    16  $1,250,000
# 2    Nov 5th 2022  Nov 13th 2022    16  $1,250,000
# 3   May 14th 2022  May 22nd 2022    16  $1,000,000
# 4   Oct 30th 2021   Nov 7th 2021    16  $2,000,000
# 5   Aug 28th 2019   Sep 8th 2019    16  $1,000,000
# 6   Feb 20th 2019   Mar 3rd 2019    16  $1,000,000
# 7   Sep 12th 2018  Sep 23rd 2018    16  $1,000,000
# 8   Jan 19th 2018  Jan 28th 2018    16  $1,000,000
# 9   Jul 16th 2017  Jul 23rd 2017    16  $1,000,000
# 10            NaN            NaN   NaN         NaN
# 11   Jul 5th 2016  Jul 10th 2016    16  $1,000,000
# 12  Mar 29th 2016   Apr 3rd 2016    16  $1,000,000
# 13  Oct 28th 2015   Nov 1st 2015    16    $250,000
# 14  Aug 20th 2015  Aug 23rd 2015    16    $250,000
# 15  Mar 12th 2015  Mar 15th 2015    16    $250,000
# 16  Nov 27th 2014  Nov 29th 2014    16    $250,000
# 17  Aug 14th 2014  Aug 17th 2014    16    $250,000
# 18  Mar 13th 2014  Mar 16th 2014    16    $250,000
# 19  Nov 28th 2013  Nov 30th 2013    16    $250,000
#
#                            location
# 0               Copenhagen, Denmark
# 1                     Paris, France
# 2            Rio de Janeiro, Brazil
# 3                  Antwerp, Belgium
# 4                 Stockholm, Sweden
# 5                   Berlin, Germany
# 6                  Katowice, Poland
# 7            London, United Kingdom
# 8   Atlanta & Boston, United States
# 9                    Krakow, Poland
# 10                              NaN
# 11                 Cologne, Germany
# 12              Columbus, Ohio, USA
# 13             Cluj-Napoca, Romania
# 14                 Cologne, Germany
# 15                 Katowice, Poland
# 16                Jönköping, Sweden
# 17                 Cologne, Germany
# 18                 Katowice, Poland
# 19                Jönköping, Sweden

# %%
import pickle

with open('df_events_stats.pkl', 'wb') as pkl_file:
    pickle.dump(df_events_stats, pkl_file)
